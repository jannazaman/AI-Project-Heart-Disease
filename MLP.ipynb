# %% [markdown]
# ## Predicting Heart Disease using MLP
# This notebook explores the performance of neural network models with different configurations, specifically varying activation functions (ReLU, Tanh), optimizers (SGD, Adam), and learning rates.
# The goal is likely to identify the optimal combination of parameters that yields the highest accuracy for predicting heart disease.

# %% [markdown]
# # Import Essential Libraries

# %%
# For generating random numbers
import random

# Essential for handling datasets using DataFrames
import pandas as pd 

# Necessary for numerical operations
import numpy as np

# To visualize relationships between features
import matplotlib.pyplot as plt
import seaborn as sns

# For the Multilayer Perceptron (MLP) classification model
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification

# For splitting datasets into training and testing sets
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Data Import

# %% [markdown]
# ### Loading In The Dataset:

# %% [markdown]
# - Reads a dataset from a CSV file into a pandas DataFrame.
# - Assigns meaningful column names for better understanding.
# - Selects specific columns relevant to the analysis.

# %%
heart = pd.read_csv("C:/Users/janna/OneDrive/Desktop/UH SPRING & Summer 2023/AI/processed.cleveland.data.csv", header=None, names=["Age", "Sex", "CP", "trestbps", "Chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal", "num"])
heart = heart[["Age", "Sex", "CP", "trestbps", "Chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal", "num"]]

# %%
heart.head()
# Out:
#    Age  Sex  CP  trestbps  Chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num
# 0   0     6    0
# 1   3     3    2
# 2   2     7    1
# 3   0     3    0
# 4   0     3    0

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Dimensions of the dataset
print("Dimensions of the dataset:", heart.shape)

# Structure of the dataset
print("\nStructure of the dataset:")
print(heart.info())

# Display summary statistics
print("\nSummary Statistics:")
print(heart.describe())
# Out:
# Dimensions of the dataset: (303, 14)
#
# Structure of the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       303 non-null    int64
#  1   Sex       303 non-null    int64
#  2   CP        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   Chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  num       303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB
# None
#
# Summary Statistics:
#               Age         Sex          CP    trestbps        Chol         fbs  \
# ...

# %%
# Correlation Heatmap to visualize feature correlations
# Helps identify strong pos/neg relationships between variables
plt.figure(figsize=(12, 10))
correlation_matrix = heart.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Heatmap of Features')
plt.show()

# %%
# Histogram for Age Distribution
# Peaks highlight age groups with higher frequency
plt.figure(figsize=(10, 6))
sns.histplot(heart['Age'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Count plot for 'Sex' variable 
plt.figure(figsize=(6, 4))
sns.countplot(x='Sex', hue='Sex', data=heart, palette='pastel', legend=False)
plt.title('Distribution of Sex')
plt.xticks(ticks=[0, 1], labels=['Female', 'Male'])
plt.show()

# %% [markdown]
# # Data Cleaning and Preparation

# %% [markdown]
# ### Handling Missing Values

# %%
#Check for the number of missing values in data frame
heart.isnull().sum()
# Out:
# Age         0
# Sex         0
# CP          0
# trestbps    0
# Chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %% [markdown]
# ### Make Response Variable Binary

# %% [markdown]
# ###### Condition: Values greater than 0 and less than 5 seclected for transformation
# - If the condition is met, the value is set to 1; otherwise, it remains unchanged.

# %%
heart['num'] = np.where((heart['num'] > 0) & (heart['num'] < 5), 1, heart['num'])

# Print the frequency table of num
print(heart['num'].value_counts())
# Out:
# 0    164
# 1    139
# Name: num, dtype: int64

# %% [markdown]
# ### Feature and Response Variable Data Type Conversion

# %%
# Each feature is converted to the appropriate data type 'float'
heart['Age'] = heart['Age'].astype('float')
heart['Sex'] = heart['Sex'].astype('float')
heart['CP'] = heart['CP'].astype('float')
heart['trestbps'] = heart['trestbps'].astype('float')
heart['Chol'] = heart['Chol'].astype('float')
heart['fbs'] = heart['fbs'].astype('float')
heart['restecg'] = heart['restecg'].astype('float')
heart['thalach'] = heart['thalach'].astype('float')
heart['exang'] = heart['exang'].astype('float')
heart['oldpeak'] = heart['oldpeak'].astype('float')
heart['slope'] = heart['slope'].astype('float')
heart['ca'] = heart['ca'].astype('float')
heart['thal'] = heart['thal'].astype('float')

# Convert the response variable 
heart['num'] = heart['num'].astype('category')

# %%
print(heart.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       303 non-null    float64
#  1   Sex       303 non-null    float64
#  2   CP        303 non-null    float64
#  3   trestbps  303 non-null    float64
#  4   Chol      303 non-null    float64
#  5   fbs       303 non-null    float64
#  6   restecg   303 non-null    float64
#  7   thalach   303 non-null    float64
#  8   exang     303 non-null    float64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    float64
#  11  ca        303 non-null    float64
#  12  thal      303 non-null    float64
#  13  num       303 non-null    category
# dtypes: category(1), float64(13)
# memory usage: 31.3 KB
# None

# %% [markdown]
# # Data Normalization

# %% [markdown]
# Normalization ensures that all features are on a similar scale, preventing certain features from dominating the model due to their magnitude. The normalization function is applied to specific columns in the dataset.
# - Scales values between 0 and 1

# %%
def normalize(x):
    return ((x - x.min()) / (x.max() - x.min()))

# Test normalization function (should output the same result)
print(normalize(pd.Series([1, 2, 3, 4, 5])))
print(normalize(pd.Series([10, 20, 30, 40, 50])))

# Apply normalize function to data
cols_to_normalize = ['Age', 'Sex', 'CP', 'trestbps', 'Chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal']
heart[cols_to_normalize] = heart[cols_to_normalize].apply(normalize)
# Out:
# 0    0.00
# 1    0.25
# 2    0.50
# 3    0.75
# 4    1.00
# dtype: float64
# 0    0.00
# 1    0.25
# 2    0.50
# 3    0.75
# 4    1.00
# dtype: float64

# %%
# Check the data frame as of now
# Ensure that the values of features and the response variable are within expected ranges
print(heart.describe())
# Out:
#               Age         Sex          CP    trestbps        Chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.529978    0.679868    0.719472    0.355564    0.275555    0.148515
# std      0.188305    0.467299    0.320042    0.166035    0.118212    0.356198
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.395833    0.000000    0.666667    0.245283    0.194064    0.000000
# 50%      0.562500    1.000000    0.666667    0.339623    0.262557    0.000000
# 75%      0.666667    1.000000    1.000000    0.433962    0.340183    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.495050    0.600055    0.326733    0.167678    0.300330    0.228823
# ...

# %% [markdown]
# # Data Splicing

# %% [markdown]
# ### Splitting the Data
# - Separates features (X) and the target variable (Y)
# - Splits the data into training and testing sets using train_test_split
# - 80% of the data is used for training, and 20% is reserved for testing

# %%
X = heart.loc[:,heart.columns!='num']
Y = heart['num']

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=5)

# %% [markdown]
# # Model Training and Testing

# %% [markdown]
# ### ReLU - SGD - Learning Rates: 0.01 and 0.001

# %%
# Define a list of learning rates to try
learning_rates = [0.01, 0.001]

# Train and test models with different learning rates
for learning_rate in learning_rates:
    model = MLPClassifier(max_iter=1000000, random_state=5, activation='relu', solver='sgd', learning_rate_init=learning_rate)
    
    # To train the neural network model using the training data
    model.fit(X_train, Y_train)
    
    # Make prediction of the test dataset
    Y_pred = model.predict(X_test)
    
    print(f"Accuracy with learning rate {learning_rate}: {model.score(X_test, Y_test)}")
# Out:
# Accuracy with learning rate 0.01: 0.8032786885245902
# Accuracy with learning rate 0.001: 0.819672131147541

# %% [markdown]
# ### ReLU - Adam - Learning Rates: 0.01 and 0.001

# %%
# Define a list of learning rates to try
learning_rates = [0.01, 0.001]

# Train and test models with different learning rates
for learning_rate in learning_rates:
    model = MLPClassifier(max_iter=1000000, random_state=5, activation='relu', solver='adam', learning_rate_init=learning_rate)
    
    # To train the neural network model using the training data
    model.fit(X_train, Y_train)
    
    # Make prediction of the test dataset
    Y_pred = model.predict(X_test)
    
    print(f"Accuracy with learning rate {learning_rate}: {model.score(X_test, Y_test)}")
# Out:
# Accuracy with learning rate 0.01: 0.7377049180327869
# Accuracy with learning rate 0.001: 0.819672131147541

# %% [markdown]
# ### Tanh - SGD - Learning Rates: 0.01 and 0.001

# %%
#TAHN - SGD - 0.01 and 0.001

# Define a list of learning rates to try
learning_rates = [0.01, 0.001]

# Train and test models with different learning rates
for learning_rate in learning_rates:
    model = MLPClassifier(max_iter=1000000, random_state=5, activation='tanh', solver='sgd', learning_rate_init=learning_rate)
    
    # To train the neural network model using the training data
    model.fit(X_train, Y_train)
    
    # Make prediction of the test dataset
    Y_pred = model.predict(X_test)
    
    print(f"Accuracy with learning rate {learning_rate}: {model.score(X_test, Y_test)}")
# Out:
# Accuracy with learning rate 0.01: 0.8852459016393442
# Accuracy with learning rate 0.001: 0.8360655737704918

# %% [markdown]
# ### Tanh - Adam - Learning Rates: 0.01 and 0.001

# %%
# Define a list of learning rates to try
learning_rates = [0.01, 0.001]

# Train and test models with different learning rates
for learning_rate in learning_rates:
    model = MLPClassifier(max_iter=1000000, random_state=5, activation='tanh', solver='adam', learning_rate_init=learning_rate)
    
    # To train the neural network model using the training data
    model.fit(X_train, Y_train)
    
    # Make prediction of the test dataset
    Y_pred = model.predict(X_test)
    
    print(f"Accuracy with learning rate {learning_rate}: {model.score(X_test, Y_test)}")
# Out:
# Accuracy with learning rate 0.01: 0.8852459016393442
# Accuracy with learning rate 0.001: 0.8852459016393442

# %% [markdown]
# # Model Evaluation Results

# %% [markdown]
# The Tanh activation function seems effective for this task, capturing non-linear relationships in the data. Tanh with Adam and a learning rate of 0.01 appears to be a good choice based on the provided accuracy results.
